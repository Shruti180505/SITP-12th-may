# %%
class BankAccount():
    currentbalance=5000

    def __init__(self,balance,op):
        self.balance=balance
        self.op=op
    def bank(self):
      
        match self.op:
         case 1:
              print("the money has been deposited to your account")
              BankAccount.currentbalance+=self.balance
         case 2:
                print("the withdrawal has been initiated")
                BankAccount.currentbalance-=self.balance
         case 3:
                print("the current available baalnce is", BankAccount.currentbalance)

         case 4:
                  print("Thank you")
                  return False
         case _:
                  print("invalid operation")

        return True

while True:   


 print("\n------BANK MENU-----")
 print("1=deposit")
 print("2=withdrawal")
 print("3=check balance")
 print ("4=exit")
 op=int(input("enter the operation you want to perform"))
 if op==1:
     deposit=int(input("enter the deposit amount"))
     obj =BankAccount(deposit,op)
 elif op==2:
     withdrawal=int(input("enter the withdrawal amount"))
     obj=BankAccount( withdrawal,op)
 else:
     obj=BankAccount(0,op)

 status=obj.bank()
 if status == False:
   break
# Out:
# ------BANK MENU-----
# 1=deposit
# 2=withdrawal
# 3=check balance
# 4=exit
# Thank you

# %%
class Bmi():

    def __init__(self,height,weight):
        self.weight=weight
        self.height=height

    def calculatebmi(self):
        finalheight=self.height**2
        bmicalculate=self.weight/finalheight
        print("the body mass index is", bmicalculate)

height=float(input("enter the height of the person in meter"))
weight=int(input("enter the weight of erson in kgs"))
obj=Bmi(height,weight)
obj.calculatebmi()
# Out:
# the body mass index is 30.405182100601497
