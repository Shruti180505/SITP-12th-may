# %% [markdown]
# ### Class in Python
# A class is like a blueprint for creating objects.
#
# * A class defines what something is and what it can do.
# * An object is an actual instance created from that class.
#
# For example:
#
#       Car → class (blueprint)
#       My red Toyota → object (real thing created from blueprint)
#
#      Example
#     ### class Dog:
#     ### def bark(self):
#     ### print("Woof!")
#
#
# | Pillar | Meaning | Example |
# |---|---|---|
# | Encapsulation | Data ko bind karna | class Student |
# | Inheritance | Parent class ke features use karna | class Dog(Animal) |
# | Polymorphism | Same method different behavior | draw() |
# | Abstraction | Internal details hide karna | abstract class |
