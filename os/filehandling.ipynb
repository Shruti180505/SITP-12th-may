# %%
import os

# %%
file=open("poit.txt",'r')

# %%
file.read()
# Out:
# 'hello, my name is shruti sharma\ni am from jaipur\n'

# %%
file.readline()
# Out:
# 'hello, my name is shruti sharma\n'

# %%
file.readlines()
# Out:
# []

# %%
# file.close()

# %%
with open('poit.txt') as file:
    print(file.read())
# Out:
# hello, my name is shruti sharma
# i am from jaipur

# %%
file=open('poit.txt','w')
file.write("Hii, how are you")
file.close()
file=open('poit.txt','r')
file.read()
# Out:
# 'Hii, how are you'

# %%
file=open('poit1.txt','w') ### ye file exist nhi krtu thi to usne ayi bna di 
file.write("Hii, how are you")
file.close()

# %%
file=open('poit.txt','a')
file.write("I live in Jaipur")
file.close()
file=open('poit.txt','r')
file.read()
# Out:
# 'Hii, how are youI kve in JaipurI live in JaipurI live in Jaipur'

# %%
file=open('filehandling.txt','a')
file.write("I live in Jaipur")
file.close()

# %%
file=open('filehandling1.txt','x') ##x=create mode agr fle hgi to error dega agr nhi hogi to create kr dega file
file.write("I live in Jaipur")
file.close()
