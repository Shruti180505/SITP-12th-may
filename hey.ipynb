# %%
print("hello")
# Out:
# hello

# %%
num=int(input("enter a number"))
print(num)
# Out:
# 5

# %%
num=int(input("enter a number"))
print(type(num))
# Out:
# <class 'int'>

# %%
bal=5000
withdraw=int(input("enter your amount"))

if withdraw <= bal:
    print("sufficent balance")

else:
    print("insufficient balance")
# Out:
# money available

# %%
### student pass & fail

marks=int(input("enter the marks of student"))
if marks <=33:
    print("fail")

else:
    print("pass")
# Out:
# pass

# %%
signal=input("enter the signal")
if signal=="red":
  print("stop")
elif signal =="yellow":
  print("wait")
else:
  print("go")
# Out:
# stop

# %%
age=int(input("enter the age of voter"))
if age >=18:
    print("you are eligible to vote")
else:
    print("not eigible to vote")
# Out:
# you are eligible to vote

# %%
totalamount=int(input("enter your total billing amount"))
if(totalamount<99):
    moreitems=99-totalamount
if totalamount <99:
    print("add more items worth rs.", moreitems, "to avail free delivery")
else:
    print("free delivery available")
# Out:
# free delivery available

# %%
marks=int(input("enter your marks"))

if marks>0:

    if marks>90:
     print("A++")
    elif marks>80 and marks<90:
     print("A")
    elif marks>70 and marks<80:
     print("B++")
    elif marks>60 and marks<70:
     print("B")
    elif marks>50 and marks<60:
     print("C++")
    elif marks>40 and marks<50:
     print("c")
    else:
     print("fail")
     
else:
      print("enter a valid number")
# Out:
# enter a valid number

# %%
attendance=int(input("enter a number"))
marks=int(input("enter the marks"))
if attendance >=75:

    if marks >= 36:
        print("pass")
    else:
        print("fail")

else:
 print("low attendance")

# %%
pin=2005
balance=5000
pinentered= int(input("enter your pin"))
if pinentered==pin:
     
     transaction=int(input("enter the transaction amount"))
     if transaction >= balance:
         lowbalance=transaction-balance
         if balance >= transaction and transaction>0:
            print("transaction is carried out successfully")
         elif transaction<0:
            print("enter a valid amount")
         else:
               print("transaction failed rs.,is more required")
else:
    print("wrong pin entered")
# Out:
# transaction is carried out successfully
