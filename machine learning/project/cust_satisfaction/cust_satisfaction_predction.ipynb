# %%
import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("cust_satisfaction.csv")

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# 2                     satisfied   26             1142                       5
# 3       neutral or dissatisfied   25              562                       2
# 4                     satisfied   61              214                       3
# ...                         ...  ...              ...                     ...
# 103899  neutral or dissatisfied   23              192                       2
# 103900                satisfied   49             2347                       5
# 103901  neutral or dissatisfied   30             1995                       4
# 103902  neutral or dissatisfied   22             1000                       1
# 103903  neutral or dissatisfied   27             1723                       1
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                      4            5                          25
# 1                      3            1                           1
# 2                      4            5                           0
# 3                      3            2                          11
# 4                      4            3                           0
# ...                  ...          ...                         ...
# 103899                 4            2                           3
# 103900                 5            4                           0
# 103901                 4            4                           7
# 103902                 1            1                           0
# 103903                 4            1                           0
#
#         Arrival Delay in Minutes
# 0                           18.0
# 1                            6.0
# 2                            0.0
# 3                            9.0
# 4                            0.0
# ...                          ...
# 103899                       0.0
# 103900                       0.0
# 103901                      14.0
# 103902                       0.0
# 103903                       0.0
#
# [103904 rows x 12 columns]

# %%
df.head()
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
# 3  neutral or dissatisfied   25              562                       2
# 4                satisfied   61              214                       3
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# 2                 4            5                           0
# 3                 3            2                          11
# 4                 4            3                           0
#
#    Arrival Delay in Minutes
# 0                      18.0
# 1                       6.0
# 2                       0.0
# 3                       9.0
# 4                       0.0

# %%
df.head(10)
# Out:
#    Gender      Customer Type   Type of Travel     Class  \
# 0    Male     Loyal Customer  Personal Travel  Eco Plus
# 1    Male  disloyal Customer  Business travel  Business
# 2  Female     Loyal Customer  Business travel  Business
# 3  Female     Loyal Customer  Business travel  Business
# 4    Male     Loyal Customer  Business travel  Business
# 5  Female     Loyal Customer  Personal Travel       Eco
# 6    Male     Loyal Customer  Personal Travel       Eco
# 7  Female     Loyal Customer  Business travel  Business
# 8  Female     Loyal Customer  Business travel  Business
# 9    Male  disloyal Customer  Business travel       Eco
#
#               satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0  neutral or dissatisfied   13              460                       5
# 1  neutral or dissatisfied   25              235                       1
# 2                satisfied   26             1142                       5
# 3  neutral or dissatisfied   25              562                       2
# 4                satisfied   61              214                       3
# 5  neutral or dissatisfied   26             1180                       1
# 6  neutral or dissatisfied   47             1276                       2
# 7                satisfied   52             2035                       5
# 8  neutral or dissatisfied   41              853                       1
# 9  neutral or dissatisfied   20             1061                       2
#
#    Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                          25
# 1                 3            1                           1
# 2                 4            5                           0
# 3                 3            2                          11
# 4                 4            3                           0
# 5                 4            1                           0
# 6                 4            2                           9
# 7                 5            4                           4
# 8                 1            2                           0
# 9                 4            2                           0
#
#    Arrival Delay in Minutes
# 0                      18.0
# 1                       6.0
# 2                       0.0
# 3                       9.0
# 4                       0.0
# 5                       0.0
# 6                      23.0
# 7                       0.0
# 8                       0.0
# 9                       0.0

# %%
df.tail()
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 103899  neutral or dissatisfied   23              192                       2
# 103900                satisfied   49             2347                       5
# 103901  neutral or dissatisfied   30             1995                       4
# 103902  neutral or dissatisfied   22             1000                       1
# 103903  neutral or dissatisfied   27             1723                       1
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 103899                 4            2                           3
# 103900                 5            4                           0
# 103901                 4            4                           7
# 103902                 1            1                           0
# 103903                 4            1                           0
#
#         Arrival Delay in Minutes
# 103899                       0.0
# 103900                       0.0
# 103901                      14.0
# 103902                       0.0
# 103903                       0.0

# %%
df.tail(10)
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 103894    Male     Loyal Customer  Business travel  Business
# 103895  Female  disloyal Customer  Business travel       Eco
# 103896    Male     Loyal Customer  Business travel       Eco
# 103897  Female     Loyal Customer  Business travel  Business
# 103898    Male     Loyal Customer  Personal Travel       Eco
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 103894                satisfied   26              712                       5
# 103895  neutral or dissatisfied   24             1055                       1
# 103896  neutral or dissatisfied   57              867                       4
# 103897                satisfied   60             1599                       4
# 103898  neutral or dissatisfied   50             1620                       2
# 103899  neutral or dissatisfied   23              192                       2
# 103900                satisfied   49             2347                       5
# 103901  neutral or dissatisfied   30             1995                       4
# 103902  neutral or dissatisfied   22             1000                       1
# 103903  neutral or dissatisfied   27             1723                       1
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 103894                 4            5                          17
# 103895                 5            1                          13
# 103896                 3            4                           0
# 103897                 4            4                           9
# 103898                 4            2                           0
# 103899                 4            2                           3
# 103900                 5            4                           0
# 103901                 4            4                           7
# 103902                 1            1                           0
# 103903                 4            1                           0
#
#         Arrival Delay in Minutes
# 103894                      26.0
# 103895                      10.0
# 103896                       0.0
# 103897                       7.0
# 103898                       0.0
# 103899                       0.0
# 103900                       0.0
# 103901                      14.0
# 103902                       0.0
# 103903                       0.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103904 non-null  str
#  1   Customer Type               103904 non-null  str
#  2   Type of Travel              103904 non-null  str
#  3   Class                       103904 non-null  str
#  4   satisfaction                103904 non-null  str
#  5   Age                         103904 non-null  int64
#  6   Flight Distance             103904 non-null  int64
#  7   Inflight entertainment      103904 non-null  int64
#  8   Baggage handling            103904 non-null  int64
#  9   Cleanliness                 103904 non-null  int64
#  10  Departure Delay in Minutes  103904 non-null  int64
#  11  Arrival Delay in Minutes    103594 non-null  float64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 9.5 MB

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction',
#        'Age', 'Flight Distance', 'Inflight entertainment', 'Baggage handling',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='str')

# %%
df['Gender']
# Out:
# 0           Male
# 1           Male
# 2         Female
# 3         Female
# 4           Male
#            ...
# 103899    Female
# 103900      Male
# 103901      Male
# 103902    Female
# 103903      Male
# Name: Gender, Length: 103904, dtype: str

# %%
df['Customer Type']
# Out:
# 0            Loyal Customer
# 1         disloyal Customer
# 2            Loyal Customer
# 3            Loyal Customer
# 4            Loyal Customer
#                 ...
# 103899    disloyal Customer
# 103900       Loyal Customer
# 103901    disloyal Customer
# 103902    disloyal Customer
# 103903       Loyal Customer
# Name: Customer Type, Length: 103904, dtype: str

# %%
df[['Gender']]
# Out:
#         Gender
# 0         Male
# 1         Male
# 2       Female
# 3       Female
# 4         Male
# ...        ...
# 103899  Female
# 103900    Male
# 103901    Male
# 103902  Female
# 103903    Male
#
# [103904 rows x 1 columns]

# %%
df[['Gender']]
# Out:
#         Gender
# 0         Male
# 1         Male
# 2       Female
# 3       Female
# 4         Male
# ...        ...
# 103899  Female
# 103900    Male
# 103901    Male
# 103902  Female
# 103903    Male
#
# [103904 rows x 1 columns]

# %%
df[["satisfaction","Gender"]]
# Out:
#                    satisfaction  Gender
# 0       neutral or dissatisfied    Male
# 1       neutral or dissatisfied    Male
# 2                     satisfied  Female
# 3       neutral or dissatisfied  Female
# 4                     satisfied    Male
# ...                         ...     ...
# 103899  neutral or dissatisfied  Female
# 103900                satisfied    Male
# 103901  neutral or dissatisfied    Male
# 103902  neutral or dissatisfied  Female
# 103903  neutral or dissatisfied    Male
#
# [103904 rows x 2 columns]

# %%
df['Gender'].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction',
#        'Age', 'Flight Distance', 'Inflight entertainment', 'Baggage handling',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='str')

# %%
df['Customer Type'].unique()
# Out:
# <StringArray>
# ['Loyal Customer', 'disloyal Customer']
# Length: 2, dtype: str

# %%
df['Type of Travel'].unique()
# Out:
# <StringArray>
# ['Personal Travel', 'Business travel']
# Length: 2, dtype: str

# %%
df['Class'].unique()
# Out:
# <StringArray>
# ['Eco Plus', 'Business', 'Eco']
# Length: 3, dtype: str

# %%
df['Baggage handling'].nunique()
# Out:
# 5

# %%
df['Flight Distance'].nunique()
# Out:
# 3802

# %%
df['Age'].value_counts()
# Out:
# Age
# 39    2969
# 25    2798
# 40    2574
# 44    2482
# 42    2457
#       ...
# 74      47
# 76      45
# 79      42
# 78      33
# 85      17
# Name: count, Length: 75, dtype: int64

# %%
df['Flight Distance'].value_counts()
# Out:
# Flight Distance
# 337     660
# 594     395
# 404     392
# 2475    369
# 862     369
#        ...
# 1309      1
# 1219      1
# 974       1
# 1479      1
# 400       1
# Name: count, Length: 3802, dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103899    False
# 103900    False
# 103901    False
# 103902    False
# 103903    False
# Length: 103904, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(172)

# %%
df.drop_duplicates()
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# 2                     satisfied   26             1142                       5
# 3       neutral or dissatisfied   25              562                       2
# 4                     satisfied   61              214                       3
# ...                         ...  ...              ...                     ...
# 103899  neutral or dissatisfied   23              192                       2
# 103900                satisfied   49             2347                       5
# 103901  neutral or dissatisfied   30             1995                       4
# 103902  neutral or dissatisfied   22             1000                       1
# 103903  neutral or dissatisfied   27             1723                       1
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                      4            5                          25
# 1                      3            1                           1
# 2                      4            5                           0
# 3                      3            2                          11
# 4                      4            3                           0
# ...                  ...          ...                         ...
# 103899                 4            2                           3
# 103900                 5            4                           0
# 103901                 4            4                           7
# 103902                 1            1                           0
# 103903                 4            1                           0
#
#         Arrival Delay in Minutes
# 0                           18.0
# 1                            6.0
# 2                            0.0
# 3                            9.0
# 4                            0.0
# ...                          ...
# 103899                       0.0
# 103900                       0.0
# 103901                      14.0
# 103902                       0.0
# 103903                       0.0
#
# [103732 rows x 12 columns]

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull()
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction    Age  \
# 0        False          False           False  False         False  False
# 1        False          False           False  False         False  False
# 2        False          False           False  False         False  False
# 3        False          False           False  False         False  False
# 4        False          False           False  False         False  False
# ...        ...            ...             ...    ...           ...    ...
# 103899   False          False           False  False         False  False
# 103900   False          False           False  False         False  False
# 103901   False          False           False  False         False  False
# 103902   False          False           False  False         False  False
# 103903   False          False           False  False         False  False
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# 0                 False                   False             False
# 1                 False                   False             False
# 2                 False                   False             False
# 3                 False                   False             False
# 4                 False                   False             False
# ...                 ...                     ...               ...
# 103899            False                   False             False
# 103900            False                   False             False
# 103901            False                   False             False
# 103902            False                   False             False
# 103903            False                   False             False
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 0             False                       False                     False
# 1             False                       False                     False
# 2             False                       False                     False
# 3             False                       False                     False
# 4             False                       False                     False
# ...             ...                         ...                       ...
# 103899        False                       False                     False
# 103900        False                       False                     False
# 103901        False                       False                     False
# 103902        False                       False                     False
# 103903        False                       False                     False
#
# [103732 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender                        0
# Customer Type                 0
# Type of Travel                0
# Class                         0
# satisfaction                  0
# Age                           0
# Flight Distance               0
# Inflight entertainment        0
# Baggage handling              0
# Cleanliness                   0
# Departure Delay in Minutes    0
# Arrival Delay in Minutes      0
# dtype: int64

# %%
df['Age'].nunique()
# Out:
# 75

# %%
df['Customer Type'].unique()
# Out:
# <StringArray>
# ['Loyal Customer', 'disloyal Customer']
# Length: 2, dtype: str

# %%
Customer_Type_dict={'Loyal Customer':1,'disloyal Customer':2}

# %%
df['Customer Type']=df['Customer Type'].map(Customer_Type_dict)

# %%
df['Type of Travel'].unique()
# Out:
# <StringArray>
# ['Personal Travel', 'Business travel']
# Length: 2, dtype: str

# %%
Type_of_Travel_dict={'Personal Travel':1,'Business travel':2}

# %%
df['Type of Travel']=df['Type of Travel'].map(Type_of_Travel_dict)

# %%
df['Class'].unique()
# Out:
# <StringArray>
# ['Eco Plus', 'Business', 'Eco']
# Length: 3, dtype: str

# %%
Class_dict ={'Eco Plus':1,'Business':2,'Eco':3}

# %%
df['Class']=df['Class'].map(Class_dict)

# %%
df['satisfaction'].unique()
# Out:
# <StringArray>
# ['neutral or dissatisfied', 'satisfied']
# Length: 2, dtype: str

# %%
satisfaction_dict={'neutral or dissatisfied':1,'satisfied':2}

# %%
df['satisfaction']=df['satisfaction'].map(satisfaction_dict)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 103422 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103422 non-null  str
#  1   Customer Type               84517 non-null   float64
#  2   Type of Travel              103422 non-null  int64
#  3   Class                       103422 non-null  str
#  4   satisfaction                58636 non-null   float64
#  5   Age                         103422 non-null  int64
#  6   Flight Distance             103422 non-null  int64
#  7   Inflight entertainment      103422 non-null  int64
#  8   Baggage handling            103422 non-null  int64
#  9   Cleanliness                 103422 non-null  int64
#  10  Departure Delay in Minutes  103422 non-null  int64
#  11  Arrival Delay in Minutes    103422 non-null  float64
# dtypes: float64(3), int64(7), str(2)
# memory usage: 10.3 MB

# %%
df
# Out:
#         Gender  Customer Type  Type of Travel     Class  satisfaction  Age  \
# 0         Male            1.0               1  Eco Plus           1.0   13
# 1         Male            NaN               2  Business           1.0   25
# 2       Female            1.0               2  Business           NaN   26
# 3       Female            1.0               2  Business           1.0   25
# 4         Male            1.0               2  Business           NaN   61
# ...        ...            ...             ...       ...           ...  ...
# 103899  Female            NaN               2       Eco           1.0   23
# 103900    Male            1.0               2  Business           NaN   49
# 103901    Male            NaN               2  Business           1.0   30
# 103902  Female            NaN               2       Eco           1.0   22
# 103903    Male            1.0               2  Business           1.0   27
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# 0                   460                       5                 4
# 1                   235                       1                 3
# 2                  1142                       5                 4
# 3                   562                       2                 3
# 4                   214                       3                 4
# ...                 ...                     ...               ...
# 103899              192                       2                 4
# 103900             2347                       5                 5
# 103901             1995                       4                 4
# 103902             1000                       1                 1
# 103903             1723                       1                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 0                 5                          25                      18.0
# 1                 1                           1                       6.0
# 2                 5                           0                       0.0
# 3                 2                          11                       9.0
# 4                 3                           0                       0.0
# ...             ...                         ...                       ...
# 103899            2                           3                       0.0
# 103900            4                           0                       0.0
# 103901            4                           7                      14.0
# 103902            1                           0                       0.0
# 103903            1                           0                       0.0
#
# [103422 rows x 12 columns]

# %%
df['Customer Type'].unique
# Out:
# <bound method Series.unique of 0         1.0
# 1         NaN
# 2         1.0
# 3         1.0
# 4         1.0
#          ...
# 103899    NaN
# 103900    1.0
# 103901    NaN
# 103902    NaN
# 103903    1.0
# Name: Customer Type, Length: 103422, dtype: float64>

# %%
df.drop(['Gender','Age'],axis=1,inplace=True)

# %%
df
# Out:
#         Customer Type  Type of Travel     Class  satisfaction  \
# 0                 1.0               1  Eco Plus           1.0
# 1                 NaN               2  Business           1.0
# 2                 1.0               2  Business           NaN
# 3                 1.0               2  Business           1.0
# 4                 1.0               2  Business           NaN
# ...               ...             ...       ...           ...
# 103899            NaN               2       Eco           1.0
# 103900            1.0               2  Business           NaN
# 103901            NaN               2  Business           1.0
# 103902            NaN               2       Eco           1.0
# 103903            1.0               2  Business           1.0
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# 0                   460                       5                 4
# 1                   235                       1                 3
# 2                  1142                       5                 4
# 3                   562                       2                 3
# 4                   214                       3                 4
# ...                 ...                     ...               ...
# 103899              192                       2                 4
# 103900             2347                       5                 5
# 103901             1995                       4                 4
# 103902             1000                       1                 1
# 103903             1723                       1                 4
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 0                 5                          25                      18.0
# 1                 1                           1                       6.0
# 2                 5                           0                       0.0
# 3                 2                          11                       9.0
# 4                 3                           0                       0.0
# ...             ...                         ...                       ...
# 103899            2                           3                       0.0
# 103900            4                           0                       0.0
# 103901            4                           7                      14.0
# 103902            1                           0                       0.0
# 103903            1                           0                       0.0
#
# [103422 rows x 10 columns]

# %%
x=df['Type of Travel']
y=df['satisfaction']
plt.barh(x,y)
# Out:
# <BarContainer object of 103422 artists>
