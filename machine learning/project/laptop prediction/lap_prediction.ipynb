# %%
import pandas as pd
# Out:
# Running cells with '.venv (3.14.5) (Python 3.14.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/Users/OYO/Desktop/Python/SITP-12th-may/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
df= pd.read_csv("data.csv")

# %%
df

# %%
df.info()

# %%
df.columns

# %%
df.info()

# %%
df['brand']
